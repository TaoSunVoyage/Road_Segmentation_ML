# %%
import numpy as np 
import os
import cv2

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras import backend as keras

import matplotlib.pyplot as plt

# %%
def f1_score(y_true, y_pred):
    y_true = y_true[:,:,:,-1]
    y_pred = y_pred[:,:,:,-1]
    c1 = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    c2 = K.sum(K.round(K.clip(y_pred, 0, 1)))
    c3 = K.sum(K.round(K.clip(y_true, 0, 1)))
    f1_score = (2*c1)/(c2+c3)

    return f1_score

# %%
def loss_f1(y_true, y_pred):
    y_true = y_true[:,:,:,-1]
    y_pred = y_pred[:,:,:,-1]
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred)
    return 1-(2. * intersection) / (union)

# %%
def unet(input_size = (256, 256, 3)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', 
                                               kernel_initializer = 'he_normal'
                                               )(inputs)
    
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', 
                                               kernel_initializer = 'he_normal'
                                               )(conv1)
    
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', 
                                                kernel_initializer = 'he_normal'
                                                )(pool1)
    
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', 
                                                kernel_initializer = 'he_normal'
                                                )(conv2)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', 
                                                kernel_initializer = 'he_normal'
                                                )(pool2)
    
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(conv3)
    
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', 
                                                kernel_initializer = 'he_normal'
                                                )(pool3)
    
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', 
                                                kernel_initializer = 'he_normal'
                                                )(conv4)
    
    drop4 = Dropout(0.5)(conv4)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', 
                                                 kernel_initializer = 'he_normal'
                                                 )(pool4)
    
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', 
                                                 kernel_initializer = 'he_normal'
                                                 )(conv5)
    
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', 
                                              kernel_initializer = 'he_normal'
                                              )(UpSampling2D(size = (2,2))(drop5))
    
    merge6 = concatenate([drop4,up6])
    
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(merge6)
    
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same',
                                              kernel_initializer = 'he_normal'
                                              )(UpSampling2D(size = (2,2))(conv6))
    
    merge7 = concatenate([conv3,up7])
    
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(merge7)
    
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal'
                                                )(conv7)

    
    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same',
                                              kernel_initializer = 'he_normal'
                                              )(UpSampling2D(size = (2,2))(conv7))
    
    merge8 = concatenate([conv2,up8])
    
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(merge8)
    
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same',
                                                kernel_initializer = 'he_normal'
                                                )(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same',
                                             kernel_initializer = 'he_normal'
                                             )(UpSampling2D(size = (2,2))(conv8))
    
    merge9 = concatenate([conv1,up9])
    
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same',
                                               kernel_initializer = 'he_normal'
                                               )(merge9)
    
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same',
                                               kernel_initializer = 'he_normal'
                                               )(conv9)
    
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same',
                                              kernel_initializer = 'he_normal'
                                              )(conv9)
    
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = Model(inputs = inputs, outputs = conv10)

    model.compile(optimizer = Adam(lr = 1e-3), loss =loss_f1, metrics = [f1_score,'accuracy'])
    
    
    return model

# %%
print('*'*30)
print('Loading and preprocessing train data...')
print('*'*30)
file = h5py.File('Dataset_train.h5', 'r')
imgs_train = file.get('images')
imgs_mask_train = file.get('masks')
imgs_train = np.array(imgs_train)
imgs_mask_train = np.array(imgs_mask_train)

imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std

imgs_mask_train = imgs_mask_train.astype('float32')
imgs_mask_train /= 255  # scale masks to [0, 1]

print('*'*30)
print('Creating and compiling model...')
print('*'*30)
model = unet()
model_checkpoint = ModelCheckpoint('weights.h5', monitor='val_loss', save_best_only=True)
tensorboard = TensorBoard(log_dir='tensorboard/', write_graph=True, write_images=True)
# Out:
# ******************************
# Loading and preprocessing train data...
# ******************************
# ******************************
# Creating and compiling model...
# ******************************

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 128, 128, 128 73856       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 128, 128, 128 147584      conv2d_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 256)  295168      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 512)  1180160     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_31[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 512)  0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 512)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 1024) 9438208     conv2d_33[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 1024) 0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 32, 32, 1024) 0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 1024) 0           dropout_3[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_36[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 512)  0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 512)  0           conv2d_30[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 128, 128, 256 0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 256 0           conv2d_28[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 128, 128, 128 295040      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 128 147584      conv2d_42[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 256, 256, 128 0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 128 0           conv2d_26[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 256, 256, 2)  1154        conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 256, 256, 1)  3           conv2d_47[0][0]
# ==================================================================================================
# Total params: 31,032,837
# Trainable params: 31,032,837
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
imgs_train.shape
# Out:
# (100, 256, 256, 3)

# %%
imgs_mask_train.shape
# Out:
# (100, 256, 256, 1)

# %%
print('*'*30)
print('Fitting model...')
print('*'*30)
history =  model.fit(imgs_train, imgs_mask_train, batch_size=2, epochs=50, verbose=2, shuffle=True,
          validation_split=0.2,
          callbacks=[model_checkpoint, tensorboard])
# Out:
# ******************************
# Fitting model...
# ******************************
# Train on 80 samples, validate on 20 samples
# Epoch 1/50
#  - 31s - loss: 0.7181 - f1_score: 0.3193 - acc: 0.2103 - val_loss: 0.7090 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 2/50
#  - 25s - loss: 0.7179 - f1_score: 0.3269 - acc: 0.1969 - val_loss: 0.7073 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 3/50
#  - 25s - loss: 0.7166 - f1_score: 0.3268 - acc: 0.1969 - val_loss: 0.7058 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 4/50
#  - 25s - loss: 0.7159 - f1_score: 0.3263 - acc: 0.1969 - val_loss: 0.7042 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 5/50
#  - 25s - loss: 0.7147 - f1_score: 0.3261 - acc: 0.1969 - val_loss: 0.7028 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 6/50
#  - 25s - loss: 0.7136 - f1_score: 0.3261 - acc: 0.1969 - val_loss: 0.7014 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 7/50
#  - 25s - loss: 0.7112 - f1_score: 0.3270 - acc: 0.1969 - val_loss: 0.7001 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 8/50
#  - 25s - loss: 0.7112 - f1_score: 0.3261 - acc: 0.1969 - val_loss: 0.6988 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 9/50
#  - 25s - loss: 0.7094 - f1_score: 0.3266 - acc: 0.1969 - val_loss: 0.6976 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 10/50
#  - 25s - loss: 0.7088 - f1_score: 0.3263 - acc: 0.1969 - val_loss: 0.6964 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 11/50
#  - 25s - loss: 0.7089 - f1_score: 0.3254 - acc: 0.1969 - val_loss: 0.6952 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 12/50
#  - 25s - loss: 0.7063 - f1_score: 0.3266 - acc: 0.1969 - val_loss: 0.6942 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 13/50
#  - 25s - loss: 0.7054 - f1_score: 0.3266 - acc: 0.1969 - val_loss: 0.6931 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 14/50
#  - 25s - loss: 0.7048 - f1_score: 0.3263 - acc: 0.1969 - val_loss: 0.6921 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 15/50
#  - 25s - loss: 0.7033 - f1_score: 0.3268 - acc: 0.1969 - val_loss: 0.6911 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 16/50
#  - 18s - loss: 0.7035 - f1_score: 0.3259 - acc: 0.1969 - val_loss: 0.6902 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 17/50
#  - 18s - loss: 0.7010 - f1_score: 0.3273 - acc: 0.1969 - val_loss: 0.6893 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 18/50
#  - 18s - loss: 0.7020 - f1_score: 0.3258 - acc: 0.1969 - val_loss: 0.6884 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 19/50
#  - 18s - loss: 0.7012 - f1_score: 0.3259 - acc: 0.1969 - val_loss: 0.6876 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 20/50
#  - 18s - loss: 0.7004 - f1_score: 0.3259 - acc: 0.1969 - val_loss: 0.6868 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 21/50
#  - 18s - loss: 0.6990 - f1_score: 0.3265 - acc: 0.1969 - val_loss: 0.6860 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 22/50
#  - 18s - loss: 0.6981 - f1_score: 0.3267 - acc: 0.1969 - val_loss: 0.6852 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 23/50
#  - 18s - loss: 0.6984 - f1_score: 0.3259 - acc: 0.1969 - val_loss: 0.6844 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 24/50
#  - 18s - loss: 0.6977 - f1_score: 0.3259 - acc: 0.1969 - val_loss: 0.6838 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 25/50
#  - 18s - loss: 0.6959 - f1_score: 0.3269 - acc: 0.1969 - val_loss: 0.6831 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 26/50
#  - 18s - loss: 0.6960 - f1_score: 0.3264 - acc: 0.1969 - val_loss: 0.6824 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 27/50
#  - 18s - loss: 0.6956 - f1_score: 0.3262 - acc: 0.1969 - val_loss: 0.6818 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 28/50
#  - 18s - loss: 0.6941 - f1_score: 0.3270 - acc: 0.1969 - val_loss: 0.6812 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 29/50
#  - 18s - loss: 0.6950 - f1_score: 0.3258 - acc: 0.1969 - val_loss: 0.6806 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 30/50
#  - 18s - loss: 0.6933 - f1_score: 0.3268 - acc: 0.1969 - val_loss: 0.6800 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 31/50
#  - 18s - loss: 0.6934 - f1_score: 0.3263 - acc: 0.1969 - val_loss: 0.6794 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 32/50
#  - 18s - loss: 0.6931 - f1_score: 0.3261 - acc: 0.1969 - val_loss: 0.6789 - val_f1_score: 0.3428 - val_acc: 0.2112
# Epoch 33/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-ba0a3ea62ab0> in <module>()
#       4 history =  model.fit(imgs_train, imgs_mask_train, batch_size=2, epochs=50, verbose=2, shuffle=True,
#       5           validation_split=0.2,
# ----> 6           callbacks=[model_checkpoint, tensorboard])
#
# D:\python\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# D:\python\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# D:\python\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# D:\python\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# D:\python\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
